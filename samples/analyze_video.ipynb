# %%
# import libraries
import os, sys
import sys
import random
import math
import numpy as np
import scipy.misc
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco
import matplotlib
import matplotlib.pyplot as plt

# define random colors
def random_colors(N):
    np.random.seed(1)
    colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors
#apply mask to image
def apply_mask(image, mask, color, alpha=0.5):
    for n, c in enumerate(color):
        image[:, :, n] = np.where(mask == 1, image[:, :, n] * (1 - alpha) + alpha * c, image[:, :, n])
    return image
#take the image and apply the mask, box, and Label
def display_instances(image, boxes, masks, ids, names, scores):
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)
    if not n_instances:
         print("NO INSTANCES TO DISPLAY")
    else:
         assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]
    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue
        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        score = scores[i] if scores is not None else None
        caption = '{} {:.2f}'.format(label, score) if score else label
        mask = masks[:, :, i]
        image = apply_mask(image, mask, color)
        image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        image = cv2.putText(
        image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2)
    return image

# %%
#Mask R-CNN
MODEL_DIR = os.path.join(ROOT_DIR, "logs")
VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "savedimgs")
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 3

config = InferenceConfig()
config.display()

# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)


class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     3
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 3
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
import cv2
video = cv2.VideoCapture(os.path.join(VIDEO_DIR, "testvideo.mp4"))
# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split(".")
if int(major_ver) < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))
try:
     if not os.path.exists(VIDEO_SAVE_DIR):
        os.makedirs(VIDEO_SAVE_DIR)
except OSError:
    print ("Error: Creating directory of data")
frames = []
frame_count = 0
while True:
    ret, frame = video.read() 
    if not ret:
        break
    # Save each frame of the video to a list
    frame_count += 1
    frames.append(frame)
    print('frame_count :{0}'.format(frame_count))
    if len(frames) == 3:
        results = model.detect(frames, verbose=0)
        print("predicted")
        for i, item in enumerate(zip(frames, results)):
            frame = item[0]
            r = item[1]
            frame = display_instances(
            frame, r["rois"], r["masks"], r["class_ids"], class_names, r["scores"])
            name = '{0}.jpg'.format(frame_count + i - 3)
            name = os.path.join(VIDEO_SAVE_DIR, name)
            cv2.imwrite(name, frame)
            print('writing to file:{0}'.format(name))
        # Clear the frames array to start the next batch
        frames = []
video.release()
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 30.0
# frame_count :1
# frame_count :2
# frame_count :3
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\0.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\1.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\2.jpg
# frame_count :4
# frame_count :5
# frame_count :6
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\3.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\4.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\5.jpg
# frame_count :7
# frame_count :8
# frame_count :9
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\6.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\7.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\8.jpg
# frame_count :10
# frame_count :11
# frame_count :12
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\9.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\10.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\11.jpg
# frame_count :13
# frame_count :14
# frame_count :15
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\12.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\13.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\14.jpg
# frame_count :16
# frame_count :17
# frame_count :18
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\15.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\16.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\17.jpg
# frame_count :19
# frame_count :20
# frame_count :21
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\18.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\19.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\20.jpg
# frame_count :22
# frame_count :23
# frame_count :24
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\21.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\22.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\23.jpg
# frame_count :25
# frame_count :26
# frame_count :27
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\24.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\25.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\26.jpg
# frame_count :28
# frame_count :29
# frame_count :30
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\27.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\28.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\29.jpg
# frame_count :31
# frame_count :32
# frame_count :33
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\30.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\31.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\32.jpg
# frame_count :34
# frame_count :35
# frame_count :36
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\33.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\34.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\35.jpg
# frame_count :37
# frame_count :38
# frame_count :39
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\36.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\37.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\38.jpg
# frame_count :40
# frame_count :41
# frame_count :42
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\39.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\40.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\41.jpg
# frame_count :43
# frame_count :44
# frame_count :45
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\42.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\43.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\44.jpg
# frame_count :46
# frame_count :47
# frame_count :48
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\45.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\46.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\47.jpg
# frame_count :49
# frame_count :50
# frame_count :51
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\48.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\49.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\50.jpg
# frame_count :52
# frame_count :53
# frame_count :54
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\51.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\52.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\53.jpg
# frame_count :55
# frame_count :56
# frame_count :57
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\54.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\55.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\56.jpg
# frame_count :58
# frame_count :59
# frame_count :60
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\57.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\58.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\59.jpg
# frame_count :61
# frame_count :62
# frame_count :63
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\60.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\61.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\62.jpg
# frame_count :64
# frame_count :65
# frame_count :66
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\63.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\64.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\65.jpg
# frame_count :67
# frame_count :68
# frame_count :69
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\66.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\67.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\68.jpg
# frame_count :70
# frame_count :71
# frame_count :72
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\69.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\70.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\71.jpg
# frame_count :73
# frame_count :74
# frame_count :75
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\72.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\73.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\74.jpg
# frame_count :76
# frame_count :77
# frame_count :78
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\75.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\76.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\77.jpg
# frame_count :79
# frame_count :80
# frame_count :81
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\78.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\79.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\80.jpg
# frame_count :82
# frame_count :83
# frame_count :84
# predicted
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\81.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\82.jpg
# writing to file:D:\Programming\droomba-image-recognition\videos\savedimgs\83.jpg

# %%
#Create a video from a list of segmented images.
import glob
import os
def make_video(outvid, images=None, fps=30, size=None, is_color=True, format="FMP4"):
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))
outvid = os.path.join(VIDEO_DIR, "testoutput.mp4")
make_video(outvid, images, fps=30)
# Out:
# <VideoWriter 0000022A02929350>
